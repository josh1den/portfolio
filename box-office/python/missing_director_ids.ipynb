# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup
import json
import time

# %%
url = "https://www.imdb.com/find/?q="
name = "Guillermo Del Toro"
response = requests.get(url+name, headers={'User-Agent': 'Mozilla/5.0'})
soup = BeautifulSoup(response.text, 'html.parser')

# %%
script_tag = soup.find('script', {'type': 'application/json'})
json_string = script_tag.string
data = json.loads(json_string)
data['props']['pageProps']['nameResults']['results'][0]['id']
# Out:
# 'nm0868219'

# %%
data
# Out:
# {'props': {'pageProps': {'findPageMeta': {'searchTerm': 'bruce mcculloch',
#     'includeAdult': False,
#     'isExactMatch': False},
#    'nameResults': {'results': [{'id': 'nm0567126',
#       'displayNameText': 'Bruce McCulloch',
#       'knownForJobCategory': 'Actor',
#       'knownForTitleText': 'The Kids in the Hall',
#       'knownForTitleYear': '1988–2021',
#       'avatarImageModel': {'url': 'https://m.media-amazon.com/images/M/MV5BNzI3OTk4MDkxOF5BMl5BanBnXkFtZTgwOTE4MDY1MjE@._V1_.jpg',
#        'maxHeight': 375,
#        'maxWidth': 500,
#        'caption': 'Bruce McCulloch in The Kids in the Hall (1988)'}},
#      {'id': 'nm13189775',
#       'displayNameText': 'Bruce Mcculloch',
#       'knownForJobCategory': 0,
#       'knownForTitleText': 0,
#       'knownForTitleYear': 0},
#      {'id': 'nm15134368',
#       'displayNameText': 'Joyce McCulloch',
#       'knownForJobCategory': 'Self',
#       'knownForTitleText': 'Landline',
#       'knownForTitleYear': '1991– '},
# ...

# %%
def scrape_missing_names(row, column):
    name = row[column]
    url = "https://www.imdb.com/find/?q="
    response = requests.get(url+name, headers={'User-Agent': 'Mozilla/5.0'})
    soup = BeautifulSoup(response.text, 'html.parser')
    time.sleep(.2)
    script_tag = soup.find('script', {'type': 'application/json'})
    json_string = script_tag.string
    data = json.loads(json_string)
    id = data['props']['pageProps']['nameResults']['results'][1]['id']
    time.sleep(.2)
    
    return id
